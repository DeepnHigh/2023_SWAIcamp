# %% [markdown]
# ## Word2vec

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from gensim.models.keyedvectors import KeyedVectors
# word2vec 벡터 파일 불러오기 (links.txt의 1. GoogleNews-vectors-negative300.bin.gz)
# 경로 수정 필요
# !cp drive/MyDrive/GoogleNews-vectors-negative300.bin.gz .
# !gunzip -k GoogleNews-vectors-negative300.bin.gz

# %%
# model 선언
model = KeyedVectors.load_word2vec_format("./GoogleNews-vectors-negative300.bin",binary=True,limit=60000)
print(model['apple'])

# %%
# 유사도 비교
print("similarity between apple and fruit: {:.3f}".format(model.similarity("apple", "fruit")))
print("similarity between apple and car: {:.3f}".format(model.similarity("apple", "car")))
print(model.most_similar("apple", topn=10))
# Out:
# similarity between apple and fruit: 0.641
# similarity between apple and car: 0.128
# [('apples', 0.7203598022460938), ('pear', 0.6450696587562561), ('fruit', 0.6410146355628967), ('berry', 0.6302294731140137), ('pears', 0.6133961081504822), ('strawberry', 0.6058261394500732), ('peach', 0.6025873422622681), ('potato', 0.596093475818634), ('grape', 0.5935864448547363), ('blueberry', 0.5866668224334717)]

# %%
# king, women, man
print(model.most_similar(positive=['king', 'woman'], negative=['man'], topn=3))
# Out:
# [('queen', 0.7118192911148071), ('monarch', 0.6189674139022827), ('princess', 0.5902431011199951)]

# %%
print(model.most_similar(positive=['dog', 'child'], negative=['adult'], topn=3))
# Out:
# [('puppy', 0.6720112562179565), ('pooch', 0.6400539875030518), ('pup', 0.612525224685669)]

# %% [markdown]
# ## 한글 Word2vec

# %%
import gensim
# train이 완료된 한글 벡터 불러오기 (links.txt의 2. ko.zip 다운받아 압축풀기)
# 경로 수정 필요
ko_model = gensim.models.Word2Vec.load('/content/drive/MyDrive/ko.bin')

# %%
ko_model.wv.vectors.shape
# Out:
# (30185, 200)

# %%
ko_model.wv.most_similar("강아지")
# Out:
# [('고양이', 0.7290452718734741),
#  ('거위', 0.7185635566711426),
#  ('토끼', 0.7056223154067993),
#  ('멧돼지', 0.6950401067733765),
#  ('엄마', 0.6934334635734558),
#  ('난쟁이', 0.6806551218032837),
#  ('한마리', 0.6770296096801758),
#  ('아가씨', 0.6750352382659912),
#  ('아빠', 0.6729634404182434),
#  ('목걸이', 0.6512460708618164)]

# %%
print(ko_model.wv.most_similar(positive=['개', '어린이'], negative=['어른'], topn=5))
# 영어만큼 충분히 학습되지 못해서 성능이 떨어짐
# Out:
# [('개의', 0.6035549640655518), ('개소', 0.5080667734146118), ('군데', 0.49295181035995483), ('전시실', 0.4303102493286133), ('점자', 0.41103148460388184)]

# %% [markdown]
# ## 카카오톡 단어벡터 만들기

# %%
import re
# !pip install konlpy
from konlpy.tag import Okt
from tqdm import tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.8/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)

# %%
# 불용어 정의
with open('stopwords.txt', 'r') as f:
  stopwords = f.readline().split(',')

# 형태소 분석기
okt = Okt()

# 학생들 각자의 카카오톡 대화 파일 열기
with open('카카오톡 대화.txt', 'r') as f:
  line = f.readline()
  corpus = []
  cnt = 0
  while line:
    # url 제거
    if 'https://' not in line:
      # 개행 제거
      line = line.strip('\n')
      # 날짜와 시간, 사람이름 제거
      if ' : ' in line : 
       line = line[line.index(' : ')+2:]
      # 영어와 한글 빼고 제거
      line = re.sub('[^A-Za-z0-9가-힣]', ' ', line)
      # 불용어 제거
      tokens = okt.morphs(line, stem=True) # 토큰화
      sentence = []
      for token in tokens : 
        if token not in stopwords:
          sentence.append(token)
      corpus.append(sentence)
    line = f.readline()
print(corpus)
# Out:
# [['자연어', '처리', '딥', '러닝', '1499', '님', '카카오', '톡', '대화'], ['2022년', '12월', '23일', '오후', '10', '39'], [], [], ['2022년', '8월', '14일', '오후', '2', '52'], ['2022년', '8월', '14일', '오후', '2', '52', '닉', '님', '나가다'], ['2022년', '8월', '14일', '오후', '3', '05', '빵', '종이', '님', '나가다'], ['파이썬', '복날', '날짜', '패키지'], ['직접', '구현', '얼른', '검색', '는'], ['절기', '십간십이지', '구현', '건', '중국인', '누군가', '거'], ['그거', '이용'], ['글쿤', '감사하다'], ['별', '말씀'], [], [], ['2022년', '8월', '15일', '오전', '1', '23'], ['선생님', '컬럼', '은', '0시', '23시', '수치', '행', '은', '날짜', '인', '데이터', '행', '순서대로', '날짜', '별로', 'lstm', '모델', '넣다', '모델', '학습', '날짜', '24', '개', '숫자', '흐름', '인', '은', '학습'], ['2022년', '8월', '15일', '오전', '2', '23', '기계', '가세', '상', '지배', '한', '다니다', '나가다'], ['자연어', '처리', 'QA', '늘다', 'token', 'level', 'task', 'sentence', 'level', 'task'], ['생', '성', '볼', '지', '추출', '따르다', '다르다'], ['생', '성', 'sentence', 'generation'], [], ['추출', 'start', 'end', 'token', '찾아내다', 'task'], ['2022년', '8월', '15일', '오전', '5', '36', '알', '수', '님', '나가다'], ['2022년', '8월', '15일', '오후', '12', '26', '님', '들어오다'], ['aaai', '2023', '제출', '분', '중', '제출', '파일'], ['재현', '코드', 'appendix'], ['작년', '엔'], ['제출', '저자', '정보', '도', '다', '날리다'], ['올리다', '맞다'], [], ['넵', '감사하다'], ['수고'], ['2022년', '8월', '15일', '오후', '1', '31', '블럭', '무', '트리', '는', '라이언', '님', '들어오다'], ['사진'], ['대', '한', '독립', '날', '감사', '마음', '보아'], ['자연어', '처리', '분', '들이다', '다', '사진', '위', '한자', '는'], ['대한민국', '임시정부', '국무원'], ['대한민국', '원년', '10월', '11일', '사진'], ['임정', '원년', '면', '1919년', '거', '아마', '단군', '최대', '격동', '기', '시절'], ['2022년', '8월', '15일', '오후', '1', '43', '블럭', '무', '트리', '는', '라이언', '님', '나가다'], ['이모티콘'], ['사진'], ['이모티콘'], ['자연어', '처리', '는'], ['torch', 'hugging'], ['읍읍'], ['경솔하다', '희다', '희다'], ['는', '국문과', '게', '자다', '읽히다', '좋다', '뜻', '받아들이다', '감사하다'], ['여담', '가깝다', '주제'], ['블루투스', '키', '보드', '추천', '가능하다'], ['아이패드', '용', '쓰다', '후기', '좋다', '은', '게', '자다', '안'], ['K', '380', '키크', '론', 'K', '3', '해피', '해킹'], ['아이패드', '로만', '쓸다', '거고', '자주', '나가시', '면', '가볍다', '거'], ['거치', '쓸다', '건데', 'pc', '키', '보드', '공용', '쓸다', '거', '면', 'MX', 'keys', '블투', '전환', '빠르다', '거', '추천', '드리다'], ['gpt', '파인튜닝', '모델', 'raw', '학습', '도', '자주', '방향', '인가요'], ['잘알다', '죵'], ['콜링', '결과', '죠', '한국', '치면', '내일'], ['나비스', '콜링'], [], ['내일'], ['2022년', '8월', '15일', '오후', '8', '07', '님', '나가다'], ['특정', '문자', '만', '나머지', '다', '지우다'], ['정규표현식', '쓰리다', '안', '잡히다', '자세하다', '설명', '해주다', '포스트'], ['구글링', '해도', '이상하다', '안', '잡히다', '뭐', '잘못', '된거', '무지하다', '자다'], ['서브', '워드', '나뉘다', '토큰', '라벨', '값', 'align', '해주다', 'huggingface', 'fast', 'tokenizer', 'word', 'ids', '메', '소드'], ['BertTokenizerFast', '토큰', '화', 'close', 'by', '특수', '기호', 'cls', 'close', 'by', 'sep', '토큰', '화', 'tokens', 'word', 'ids', 'None', '0', '1', '2', 'None'], ['원하다', '결과', '는', 'None', '0', '0', '0', 'None'], ['전', '이분', '포스트', '참고'], ['감사하다'], ['사용', 'regex', '입출력', '보여주다', '고수', '님', '잡다', '겁니다'], ['안녕하다'], ['play', 'the', 'top', '20', 'rita', 'macneil', 'songs', '토큰', '화'], ['CLS', 'play', 'the', 'top', '20', 'rita', 'mac', 'neil', 'songs', 'SEP'], ['None', '0', '1', '2', '2', '2', '3', '4', '4', '5', 'None', '실제', '단어', '인덱스', '맞추다', '직접', '구현'], ['사진'], ['메', '소드', '사용'], ['CLS', 'play', 'the', 'top', '20', 'rita', 'mac', 'neil', 'songs', 'SEP', '토큰', '화'], ['None', '0', '1', '2', '3', '4', '5', '6', '6', '7', 'None', '음'], ['단어', '사이', '띄어쓰기', '특수', '기호', '붙다', '경우', '저렇게'], ['생각나다', '해결', '책', '문자열', '띄어쓰기', '기준', 'split', '후', '초', '단어', '별로', '토큰', '화', '비', '효율', '적', '인'], ['word', 'ids', '원리', 'bpe', 'tokenize', '친구', 'word', '인식'], ['띄어쓰기', '기준', 'word', '인식', '짜다', '직접', '구현', '방법'], ['데이터', '띄어쓰기', '기준', '단어', '별로', '태깅'], ['nltk', 'mecab', 'whitespace', 'tokenizer', '다'], ['감사하다', 'pretrain', 'bert', '모델', '사용', 'tokenizer', '바꾸다'], ['학습', '해', '야합', '니', '다'], ['아카이브', 'latex', '양식', '은', '어디서'], [], ['2022년', '8월', '16일', '오전', '12', '05'], ['학회', '양식'], ['Batch', 'size', '1', '줄이다', 'Out', 'Of', 'Memory', '뜨다', '이르다', '길이', '기다', 'sentence', 'filtering'], ['max', 'sequence', 'length', '절반' ...

# %%
print(corpus[:10])
# Out:
# [['자연어', '처리', '딥', '러닝', '1499', '님', '카카오', '톡', '대화'], ['2022년', '12월', '23일', '오후', '10', '39'], [], [], ['2022년', '8월', '14일', '오후', '2', '52'], ['2022년', '8월', '14일', '오후', '2', '52', '닉', '님', '나가다'], ['2022년', '8월', '14일', '오후', '3', '05', '빵', '종이', '님', '나가다'], ['파이썬', '복날', '날짜', '패키지'], ['직접', '구현', '얼른', '검색', '는'], ['절기', '십간십이지', '구현', '건', '중국인', '누군가', '거']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences = corpus, size = 100, window = 5, min_count = 1, workers = 4, sg = 1)

# %%
model.wv.vectors.shape
# Out:
# (14278, 100)

# %%
for word in model.wv.vocab:
  print(word)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# BartConfig
# 컨피
# 필
# 여한
# words
# Auto
# From
# plus
# convert
# Special
# AutoMdoelForSequenceClassification
# 구술
# 벑님
# 씌우다
# onehot
# 잘생기다
# 비법
# 시청
# 화장
# Logging
# sbi
# 대출
# 악질
# 금리
# 휘
# 둘리
# 연락처
# 데브
# 콘
# 취향
# 탈
# 도용
# 피해자
# KU
# dot
# 고대
# 건대
# 1월
# 일본
# 홍콩
# 근거리
# 국제
# 경희
# KKU
# 건양
# ku
# 쿠웨이트
# 유니
# 시티
# 김일성
# 종합대학
# 일리
# Kensas
# University
# 유사성
# 관련성
# 유무
# 뒤에
# 냉동
# 우회
# MultiheadAttention
# 못햇
# BERTSentenceTransform
# 썻으
# 탈락자
# 미워잉
# dic
# cannot
# execute
# 네이티
# 브
# 바이너리
# 주신문
# 미워하다
# hustle
# 몬가
# 설
# 청춘
# 아프리카
# 정훈
# summaratzation
# 부뉴
# Klue
# KoBERT
# 10001
# contexts
# PSPMI
# 관도
# 사라
# Singleton
# 텐플방
# 원자력
# 같슴닷
# 재밋겠긴
# 후려치다
# 4천
# 학졸
# 초봉
# 삼천
# 사가
# 정도에요
# Lg
# 5150
# 5450
# 취준생
# 2600
# 되쥬
# 원티드
# 양극화
# 계얄사
# 옵음
# 사해
# 뼈
# 학력
# 버클
# 바랑
# 잡부
# 마지노선
# 아영
# 칭찬
# 백이
# 협의
# 월급쟁이
# 학졸초봉
# 3100
# 졸초봉
# 3300
# 프론트엔드
# 동파
# 늦어지다
# 괜
# 남반구
# 만족
# 버는
# 시드머니
# 버는거
# 원천
# 년수
# 이여
# 현금
# 박치기
# 폭
# 늘어서다
# 레버리지
# 3200
# 버시는분
# 인분
# 민족
# 정신승리
# 평화롭다
# 보금자리
# 인상
# 700
# 아녓어
# 경고
# 합법
# 수령
# 8억
# 52시간
# 무표
# 달동
# 어휴
# 생명
# 깎다
# 노동부
# 근무
# 듣기
# 책임지다
# 컨설턴트
# 100시간
# LGCNS
# 70시간
# 5억
# 정도만
# 바짝
# 가치관
# 급여
# 부캠졸
# 둥
# 망치다
# 있쬬
# 공무원
# 초과근무
# 빡시다
# 40시간
# ot
# 임원
# 알람
# 눈치
# 법적
# 시급
# 4만원
# 비참하다
# 그쳥
# 겨
# 서른
# 늘어지다
# 얼
# 마일
# O
# 과장
# 9천
# 레인지
# 갈수록
# 격차
# 3억
# 8천
# 정도겠군요
# 세배
# 으면
# 핸즈온
# 두텁다
# 두껍다
# 두께
# 떠받다
# 일러스트
# 레이티
# ref
# 출발
# 혼합
# 학
# 졸이다
# 표면
# 가르다
# 대도
# 자의
# 협상
# 자격지심
# 하등
# 부양
# maxpooling
# nice
# 고액
# 퇴직
# 마쟈
# 야금야금
# 빠이팅
# 워싱턴
# 수상기
# 사중
# sense
# 진해
# automodelforpretraining
# Nsp
# 호옥시
# 휴리스틱
# 곤
# 짬바
# 꾀
# 중수
# 따리
# 진화
# 팔로
# 명더
# 보이시
# 받았슴다
# 적응
# 날아가다
# 캡쳐
# info
# Targrt
# 시퀀셜
# 단정하다
# 스캔
# xyz
# 좌표
# 점심
# 편차값
# 카메라
# 왜곡
# 프로토
# next
# location
# trajectory
# 잡채
# 딜리셔스
# 외한
# 채
# beautiful
# soup
# 에겐
# xpath
# cssselector
# good
# use
# 패캠
# 로나
# 메로나
# 뷰숩
# 체고
# 출출하다
# 끼니
# 때우다
# 연대
# 도서관
# 절대자
# 뷰숩선
# 자만
# selectolax
# 셀렉
# 락스
# 꺼에욬
# 친
# 이따
# 갖
# cat
# 일부분
# overlap
# 산술
# 불리언
# reduce
# 이라야
# 콜랩
# 환경설정
# matplot
# 무사하다
# 포로
# 뽀로롱
# 2351
# 9649
# 각도
# 디멘젼
# 애처
# 임베딩할때
# 전문화
# 돌림
# 6700
# 310
# Generation
# 게실
# 인퍼런스때
# rouge
# 복윈
# beam
# 마땅하다
# 달에
# generatemixin
# extend
# 2시
# 반부터
# 한동안
# 방만
# 센터
# 화재
# 친추
# Sk
# 관할
# 왠
# 어플
# Whatsapp
# 넓히다
# Pc
# 본기
# 아유
# 일반인
# 처럼만
# 위엄
# 네이버웹툰
# 뱅크
# 코카
# 펩시
# 직업
# 뭐던
# 쓸리다
# 뿌듯하다
# 의지
# 타산
# 지석
# 교사
# 레밍
# 절벽
# 릴레이
# 텔레
# 독일
# 집단
# 질주
# 어조
# 슬랙쓰네
# 영진
# 옹호
# 중학생
# 비거
# 싸우다
# 맙시
# 교훈
# 해선
# 러시
# 곱창
# 총대
# 해프닝
# 우기
# 신흥
# 하이브리드
# 오프
# 근처
# 베트남
# 음식점
# 동양
# 쌀국수
# 그리움
# 현지
# 안면트
# 아이스브레이킹
# 대접
# 박하
# 잔
# 양념치킨
# 인스턴트
# 간도
# 밍숭맹숭
# 게눈
# 간장
# 비낼태
# 아시안
# 왜간장
# 설탕
# 졸리
# 슬랙
# 무료슬랙
# 좋슴다
# 챗
# 백업
# 놔두다
# 아찔하다
# 유류
# 비호감
# sk
# cnc
# 외로
# 린다
# 카더라
# 디펜
# 평일
# 사용성
# 흐리다
# 편지
# 개뿔
# zulip
# 페이스북
# DNS
# MSA
# 넷플릭스
# ckpt
# lightning
# 용어사전
# 뱅이
# 복구
# 다시다
# 안일하다
# 사진전
# 송이
# 카뱅
# 운용
# 취약
# 버디버디
# 안쪽
# 보헤미안
# 신후
# 쉴드
# 마지막글
# 싸늘하다
# 티스토리
# 도감
# 잃어버리다
# 간신히
# 절대로
# 책임자
# Desginer
# 꼴
# 체스
# 플레이어
# 대길
# 바니
# 빌드할
# multiple
# 충격
# OPT
# 175
# 소름
# 돋다
# 박사학위
# 빗다
# 조약
# 분만
# 기점
# 다음주
# duplicated
# keep
# loc
# TrainerCallback
# adsf
# asdf
# 띄어씌까
# 계싱가
# 비단
# 결합
# parenthesis
# regexr
# 버넌스
# 딱딱하다
# 구색
# 의아
# 민간
# 걸걸
# 컨소시움
# 만들럿
# etri
# twitter
# 서칭
# 대를
# 전파
# 판교
# 사과문
# 북한
# 미사일
# 됏네
# DR
# 거만
# 주가떄문
# 자연재해
# 어쩌란거
# 그동안
# 국민
# 베겨
# 배짱
# 가동
# 체질
# disaster
# recovery
# dr
# 이중화
# 스위치
# Dr
# 익
# 중딩
# 페매
# 타격
# 페메
# 아가
# 페메한대
# 넘사벽
# 이자나
# banana
# orange
# endswith
# 녹
# 초가삼간
# 쥐피유
# 초록색
# 아이콘
# 항시
# 검거
# 성인
# 팀플
# 트온
# 인스타
# 신전
# 학생회
# 안함
# 하우스
# toxic
# sungkim
# 네넴
# deeplearn
# Hot
# 팔로우
# Montreal
# feaure
# 바나나킥
# compression
# ratios
# 곱하기
# 곱셈
# 알파벳
# abstract
# interpretability
# checkpoint
# 재개
# 을해
# 천만
# 대로는
# 10000만
# 개씩
# 이학
# support
# oprimizer
# backprop
# 120만
# 개로
# optimzer
# 적재
# WSDM
# 발롱도르
# 벤제마
# 존버
# 승리
# 레알
# 일등
# 공신
# 챔스
# 주역
# 바서
# 론데
# 더블
# 레반돕
# nlpaug
# 중론
# django
# 고안
# kerry
# 옵챗
# 예잉
# Kerry
# 모범
# Best
# Practice
# 대중
# 아레나
# cikm
# field
# 낭
# 날로
# 스탈
# voca
# 갈대
# 어디가
# imdb
# 어쩌구
# 볽
# 투척
# 구로
# 에코
# 정벅
# 차례차례
# PAD
# 마치다
# pad
# 패딩된
# podman
# mount
# volume
# destination
# workspace
# images
# Kobert
# 골고루
# 투머치
# syntactic
# role
# 에지
# 동향
# 물어
# 면바
# 5시간
# 겸상
# 랩스였던걸
# 이었던가
# 6시간
# 판도
# 판이
# 롤로
# 실버
# 실용
# 실정
# 패스트
# 캠퍼스
# 80000
# 1234
# 모트
# valueerror
# 3월
# 입학
# 보충
# 샤
# 밤새다
# 방학
# 2월
# 말부터
# tmi
# 아성
# 기쁘다
# Cs
# 아니먄
# 하여튼
# 완독
# 재정
# 리하
# 다른사람
# 드잡이
# 하고도
# 자세
# 회계학
# 깟
# 공이
# 궁훈님
# 뭉치
# 국
# 상치
# 풀엇을것
# 비정상
# 디텍션
# 엄격하다
# 벨링
# 확연
# adaption
# 내주다
# 미치나
# critical
# subssion
# archival
# workshop
# 위험
# 인정받다
# 새로윤
# MS
# MARCO
# Paperswithcode
# nifa
# Nifa
# 굼용
# 편견
# NIPA
# 닙
# sympy
# 방정식
# solve
# 스크린샷
# 펑션
# 거인
# 심볼
# exec
# xgboot
# boosting
# 매개변수
# BT
# 각인
# stanford
# winter
# wikidocs
# 똥
# 좃아
# 안정화
# 배점
# 450
# 수로
# CMT
# Phase
# 포워딩
# LATEX
# 응애
# viewed
# Each
# includes
# SMILES
# tokenized
# SELFIES
# appended
# its
# PDF
# FORM
# 털
# 힙합
# 필요시
# 작품
# Off
# 멘션
# 스팸
# 퇴장
# 조치
# 무분별
# 제재
# 제언
# CTM
# Contexutalized
# Topic
# Models
# 2021년
# coherence
# 제시
# 콘켓
# concate
# contextualized
# 태스크하
# ProdLDA
# 적인걸
# 부어
# 니트로
# 시나
# 루시
# 네이션
# AIhub
# 제격
# 부루
# 임베딩이
# 이제야
# jsonl
# OrderedDict
# stage
# 분류태스크
# 시오
# 카를
# RandomSampler
# pickle
# ganim
# gensim
# Essential
# 코리다
# 텐스
# 단기간
# 청천
# variation
# Glove
# Bag
# SEQ
# With
# ATTENTION
# TRANSFORMERS
# Combined
# Modeling
# Contextualized
# Coherence
# 오른쪽
# 왼쪽
# UI
# pyLDAvis
# 특화
# 장임
# 베딩
# 국내외
# Timestamp
# 사칙연산
# cot
# instructgpt
# 텐플코
# 게시
# 후우
# 구미
# 발견
# 발명
# 떼쓰다
# 심심찮
# 알파
# 에듀
# 리드
# 정서
# 이해도
# 콘텐츠
# 분과
# 노션
# 가족
# GCN
# 토마
# 스키
# 프
# Berto
# PoS
# BERTopic
# topics
# probabilities
# transform
# Make
# sure
# documents
# iterable
# strings
# Transform
# 캐시비
# 가비지
# 컬렉터
# 이터러블
# String
# 어려움
# Docs
# Iterable
# 앞서
# 짤려
# 따옴표
# 값일
# 젠데
# 데요
# 취하
# inf
# finetuned
# RobertaForMaskedLM
# AutoModelForCausalLM
# trinity
# NSMC
# 위키피디아
# Mlm
# 뮨장
# 혼동
# overflowing
# 제온
# 켜
# 무리다
# 씨퓨
# 도면
# SergeyBrin
# 세르게이
# 브린
# 저커버그
# 게이츠
# 결백
# 제프
# 임배딩
# 임배딩하
# 일괄
# 135
# 최윤
# 강연
# 하고는
# 백의
# 맵핑
# Digit
# Split
# Value
# Aggregation
# DSVA
# Place
# DPE
# VRAM
# 1080
# maxlength
# bigbird
# 384
# Chunking
# chunking
# Chunked
# OpenAi
# 벤치마크
# 벤치
# ECC
# 쿼드로
# 지불
# solver
# 위도
# 경도
# fix
# 일이삼
# 백이십삼
# 위경
# 백본
# 뜬구름
# 솜사탕
# 02010
# 둘러싸이다
# 020
# 010
# 우스갯소리
# 딴지
# 201
# 0만
# adamw
# AdamW
# 02010만
# putty
# 201만
# 잡아내다
# 파킨슨
# 증후군
# Vocie
# Challenge
# 과학기술
# 정보통신부
# 정보사회
# inupt
# 101
# 우영
# 고래
# 차라
# 고지
# 선제
# 시해
# 계약서
# 행동
# 내장
# wordnet
# synonyms
# antonyms
# proro
# 종
# 인터프리터
# japanese
# 요술
# 램프
# TextRank
# VSCode
# 흰색
# winodow
# extension
# 확장자
# 합니딘
# 뉴탭
# ini
# 크래스
# 파란색
# asctime
# notice
# 억지로
# 어이없다
# 억울하다
# 까오
# 억만장자
# 까마귀
# 테그
# 베르누이
# selenium
# BeautifulSoup
# DataCollatorForLanguageModeling
# wwm
# 기번
# 표본
# 비슷운
# 딥최나
# 콜
# 레이턴
# 매다
# net
# 블라블라
# 박해
# legend
# 척척
# 수해
# 이쯤
# 경험치
# 역효과
# 서일
# easy
# koeda
# BertAdam
# 엔화
# 5천원
# 정기
# Vpn
# 폭락
# 담달
# 지켜보다
# 환율
# 용하다
# 레스
# 7만원
# Tqdm
# mmcn
# VM
# Gnn
# convolution
# 234
# Za
# 싹
# 허그
# 321
# 시픙
# 마하
# 하비다
# 웹사이트
# 로잔
# 인턴쉽
# 똑똑
# 똑
# 할로윈
# 손님
# 사탕
# 코인
# 맴
# 엔솔
# 에너지
# 박지훈
# representations
# usage
# area
# vectors
# 부피
# dimensional
# formula
# 가은
# 기하학
# triangle
# sphere
# 도형
# 표준분포
# 고서
# convex
# hull
# 구멍
# 이라기보다는
# multipolygon
# points
# XAI
# 구건
# intrinsic
# 1875
# 심층
# Support
# Vector
# Machine
# suffix
# startswith
# endswiths
# Oracle
# 블렌더
# atlas
# palm
# 춘추전국시대
# 구조만
# 통채
# 없겠죵
# iterrow
# itertuples
# 무모하다
# 장해
# gcp
# 수만
# 어림
# 60만
# 개다보니
# 맥시
# Rest
# 천자
# 타임
# sleep
# 졍
# Single
# persom
# person
# Person
# getitem
# 스트리밍
# Column
# Collator
# 병목
# 하시죸
# interconnect
# 소모
# Latency
# 지연
# latency
# 병목현상
# 일련
# 소프트웨어
# 알렉스
# 포션
# 닌
# 부하
# 면도
# Cpu
# 가일
# 2019년
# Semi
# 건설
# 뗼
# 하미
# 조조
# 짱키독스
# 방대하다
# 만의
# 고충
# LRNounExtractor
# compounds
# components
# 브로맨스
# 철도
# 위후
# transition
# 태
# 스크
# README
# 취준이거
# 못지않다
# DiffCSE
# 요론
# mkdir
# EX
# generalization
# 사생
# 선형변환
# boolqa
# mcqa
# Do
# accent
# 부터가
# 형용사
# 나열하다
# 유의어
# 소로스
# thesaurus
# sliced
# chopped
# Mixed
# Precision
# 내적
# 임시
# 장공
# 비트
# 공유드랴
# propagation
# 미적분
# xlnet
# 명단
# 카글
# 븐
# 식겁하다
# 튀튀
# recommendation
# trends
# 움직임
# 유명인
# 22년
# 상관관계
# 넘어서다
# 인과관계
# 규명
# 뒤적거렸
# rec
# ColBERT
# ir
# 엘라스
# 틱
# 프런트엔드도
# 관리툴
# Adam
# Torchlight
# Bilinear
# visual
# question
# answering
# involves
# grounding
# 은닉
# 마르코프
# 방출
# 알때
# likelihood
# likeihood
# emission
# phi
# HMM
# ginve
# observable
# givne
# find
# gelu
# tanh
# 위키데이터
# 어마
# dram
# kowiki
# 4천만
# 엑
# 묘
# pyLDA
# 그린
# src
# 패딩부분
# sequnce
# enc
# depend
# 도록
# 부가
# 케글씩
# NBME
# CommonLit
# Readability
# ongoing
# Feedback
# Prize
# Google
# 105
# 깜짝
# 훅
# 종합
# Pretrain
# 천차만별
# 스케쥴
# 정신분석
# 신화
# 상징
# 고등학교
# 맵
# Symbolic
# interpretation
# 논라벨드
# focused
# 해고
# 닏
# 셰익스피어
# 히페리온
# 아폴론
# 포이
# 부스
# 에이콘
# 서적
# Latent
# Dirichlet
# Allication
# 융
# 심리학
# 원형
# 어휘
# 심리학자
# 수치화
# 규칙화
# KG
# 패턴인식
# 11월
# 추계
# 15년
# 변인
# 오시
# hanschoi
# hallucination
# won
# example
# 3333
# wonwon
# 5555
# ict
# 아호
# 라식
# 코로
# 일대
# leanring
# 욯
# 야후
# BertOnlyMLMHead
# 포크
# Lr
# 점검
# flat
# regularization
# 있쥬
# 30시
# 리즈
# emb
# scalar
# 임베딩값
# 양립
# 벗어나다
# 페가
# rmse
# 스케
# 손보
# 오버플로우
# 스케일링
# 소실
# 웅
# 리뉴얼
# yumiyumi
# 선진국
# 뒷북
# 매일경제
# 엄
# 냅다
# 쑥쑥
# 요령
# due
# 요행
# 진득
# 참으로
# 인스톨
# odqa
# retriever
# oracle
# 원안
# environment
# 무식하다
# 중견
# 연명
# topk
# 재는
# 의미론
# mathcing
# 상속
# 포켓몬빵
# 데리다
# weghts
# 유연성
# 비식
# 터졋으
# 띵띵
# 튜플
# Item
# Description
# Creative
# 봤을떈
# append
# upsampling
# 3회
# 버드
# gpus
# accelerator
# devices
# 고해
# 덩어리
# 복제
# 밋업
# 아름답다
# native
# 만으로는
# FLAX
# 임용
# Parallel
# bleu
# coco
# caption
# BLEU
# Bill
# gates
# 주커버그
# 이면서
# expend
# pretrainig
# Experiments
# 각기
# 핑프같
# GLUE
# KLUE
# advanced
# 트포
# LMkor
# bertfotmaskedlm
# Bertforpretraining
# 트포군
# PET
# Pattern
# Exploiting
# Regression
# 닽
# 개일
# happy
# sad
# 리그레
# love
# grammar
# 무작정
# conclusion
# inverse
# indexing
# 심플
# Bm
# 색인
# Exact
# ES
# MBBPE
# 를썻어
# Morpheme
# 에어팟
# 버즈
# 노캔
# 심장
# 고장
# 통화
# 음질
# 쿠팡
# 할인
# 쟁여야겟네
# Kiki
# 밑줄
# 그을
# dsfafngqerv
# 어도비
# Xodo
# Mendeley
# Pdf
# expert
# 평이
# 600
# 위대하다
# 기계학습
# 고기
# 느님
# 행마
# 대치동
# 9만
# row
# modin
# 멀티스레드
# 밖엔
# 때매
# 막심
# Cython
# 음성합성
# Dataloader
# Generator
# Acc
# 특하
# 내신
# 마음속
# 발명자
# 개떡같다
# 출원
# 양도
# 권리
# 과금
# 특허권
# 어탠션
# 화살표
# 맥주
# 음주
# 화이
# versions
# resolver
# U
# deprecated
# requirements
# unexpected
# 중단
# checkcpoint
# 재학
# 진출
# baidu
# File
# uploadfile
# UploadFile
# PIL
# Image
# jpg
# 기안
# contents
# await
# img
# BytesIO
# imdecode
# frombuffer
# uint
# CSV
# pdfplumber
# pdfminer
# easyocr
# 중첩
# 키진
# 값어치
# truth
# ambiguous
# isin
# 우대
# 컴피티션
# 옳다
# 또륵
# upgrade
# cd
# Tok
# tok
# tk
# 스트링하
# 하셔얄듯
# 즈음
# 기댓값
# 전학
# facebook
# 알리
# 후에
# 타자
# mnist
# 뚫다
# 버트형
# cloze
# BertWordPieceTokenizer
# AttributeError
# IncompatibleKeys
# kiwi
# kss
# Innorix
# 플러그인
# 캔
# 슬링
# 피라미드
# 통신사
# 불황
# 이동
# 정년
# 조직개편
# 아낌없다
# 칼
# 호황
# 불확실
# 확실성
# featrue
# 워렌
# 명언
# Eda
# 퍼셉트론
# 선형회귀
# 신경세포
# 부분집합
# 파리니
# 양질
# 페가수스
# 다니엘
# 자시다
# 코드명
# 애용
# 구글번역기
# 덕택
# 화요일
# 국립
# 분발
# 세시
# 자가
# 들보
# 기만
# child
# Child
# sage
# 시초
# 에듀윌
# 케이티
# 피아
# IP
# 공처
# errors
# might
# asynchronously
# reported
# some
# other
# stacktrace
# below
# incorrect
# debugging
# consider
# passing
# LAUNCH
# BLOCKING
# 힘내다
# spacy
# sm
# 꾸미다
# 에러메시지
# IndexError
# AB
# proxy
# Bertshared
# Https
# pool
# 떠올리다
# ul
# UL
# Unified
# Learner
# Survey
# 거짓
# 리콜
# Sage
# Ddpm
# stable
# diffusuon
# 상한
# ldm
# unet
# denoising
# 실망
# 대소문자
# Korpora
# 자하
# corpora
# korpora
# Expert
# systens
# wuth
# applcations
# 비어
# 업스
# ln
# 소라면
# 캡셔닝
# 혜택
# 59분
# 17시
# 19시
# 공휴일
# 전면
# 강남역
# 도보
# 오프라인
# 학습장
# 어머
# 생인
# 컬
# 원수
# 받쥬
# concatenation
# Output
# MSELoss
# towardsdatascience
# 신선하다
# 으로의
# 이종
# TDS
# popular
# tabular
# CoT
# Thought
# fusion
# 역쉬패캠
# 점심시간
# Bart
# 첩
# BartTokenizer
# 이상일
# 는게
# 미천하다
# 달차
# 묵념
# 2222
# 들었슴다
# 유알엘
# URL
# 기사도
# 훑어보기
# ec
# 나머진
# inventory
# 관측
# 재고
# 코렉션
# 인더
# 파킴
# 플레이
# 보답
# 온점
# autoencoder
# Cls
# bett
# 함축
# cond
# result
# clean
# strip
# 같숩니
# 뉘
# 스마트
# 세로
# 샘플러
# 설레다
# RAW
# DATA
# DIR
# trains
# loads
# pd
# DataFrame
# Csv
# lines
# orients
# records
# FileNotFoundError
# No
# Unnamed
# Jsonl
# 첫째
# 오기
# 독특하다
# Pd
# 턱
# article
# taks
# 작문
# 끌끌끌
# 못자다
# ARR
# START
# Submission
# template
# November
# Anonymity
# period
# deadline
# submitted
# December
# through
# direct
# submissions
# January
# Direct
# submission
# Commitment
# March
# Author
# Notification
# May
# Withd
# Rolling
# Review
# 한일
# 껍니
# PE
# permutation
# invariant
# accelerate
# 예의
# XG
# boost
# 보편화
# hand
# crafted
# XGBoost
# 교과서
# benchmark
# MRC
# Calibration
# calibration
# 명일
# et
# al
# 체적
# 네가지
# 갱신
# 구조일
# 양으로
# 리얼
# 재활용
# 쓰레기
# trade
# 당면
# 정책
# 관성
# 차차
# 에까지
# 소화
# soundfile
# 오디오
# waveform
# 도해
# 인지도
# 스캐터랩
# 일간
# 튜닙이
# 지령
# 섭하다
# exa
# 넝담
# 해산
# 분사
# 각출
# 노스페이스
# 컨설팅좀
# 라네
# Dp
# AutoModelForSequenceClassification
# 은혜
# 로운
# 리밋
# 어뷰징
# 주된
# authentication
# 지갑
# 쪼렙
# 기대다
# 시일
# 간정
# 입결
# 쿠사리
# 평가자
# 손쉽다
# 놀
# 변태
# 제주
# 풀라
# 연산자
# 불류
# 장도
# aihub
# impossible
# answers
# SentenceBert
# Hugging
# 권해
# 될런
# 홍콩인
# 알려쥰건데
# 아낌없이
# 둿다
# 달림
# 디펜스
# TRC
# SentenceBERT
# 유리하다
# 바람직하다
# korbigbird
# 개정도였나로
# 대고
# 덩이
# 훼영좌
# 콩글리쉬
# 페어
# sim
# 콘캣
# 공사
# 맞먹다
# 330
# 한다해
# 미루다
# 망가지다
# 10억
# rows
# 스파크
# bertsum
# kobertsum
# korbertsum
# 약용
# 불어
# 독어
# 그랬는데
# 병역
# 특례
# Adaptive
# 입원
# 원일
# Length
# Stay
# LOS
# 예약
# 노쇼
# 의무
# 식별
# 표준
# ICD
# 분당
# 대학병원
# EMR
# 학원
# 차리다
# 수능
# 과목
# 편입
# beginner
# comp
# 투어
# 김용담
# 본능
# 눌리
# 확대
# 본캐
# 사칭
# 묶이다
# 40만원
# 따로따로
# 인프런
# 미끼
# 맞아욬
# 팔리다
# 핵인
# 오라
# engineering
# vim
# 에디터
# 깨알
# 전수
# ojt
# 지겹다
# 장지원
# 섭렵
# 스푼
# 직강
# 중임
# 아카데믹
# 루트
# 스톤
# 정독
# 78569687
# 108191691
# 105294979
# 74802622
# 용담
# 서평
# 이해만
# 리릭
# 추상화
# 조급하다
# 방치
# 부지
# minmax
# leakage
# env
# AAA
# BBB
# CCC
# DDD
# 폭죽
# 손대다
# 곤해
# j
# l
# 깨우치다
# 정표
# Mechanical
# Turk
# 일후
# 구글검색
# 찬스
# 메커니즘
# 버트책
# OpenPrompt
# 통째
# Coreference
# coreference
# 상실하다
# 어르다
# sparseml
# 프루닝
# 을까요
# 지레
# 앓다
# 아누
# 희망이
# 입증
# 태클
# 장보
# Detach
# 일으키다
# 뒤쪽
# 커스터
# FFNN
# 스크래치
# KE
# squad
# kcbert
# Deberta
# 미적지근하다
# 베팅
# 디버트
# ETRI
# Techday
# 정통부
# 제법
# 발끝
# 만치
# DEEPer
# Hallucinate
# 환각
# distract
# 스타크래프트
# Hallucination
# 한소리
# 뉴욕
# 헛소리
# 풍자
# 하아
# 우먼
# 특이점
# 유우
# 관등
# Util
# 도우
# 항목
# container
# 글케
# 한도
# 403
# 지치다
# 돠려
# 멀쩡하다
# 전원
# avilable
# enabled
# manager
# 스코프
# LM
# entropy
# 코린
# 트립니
# 못정
# 인덱
# 싱하
# astype
# lambda
# 추수감사절
# 국박
# 개점
# 시민권
# 국제화
# 남고
# 군필
# 오심
# absolute
# relative
# orqa
# ICT
# maksing
# 나신
# 입낟
# anser
# 꽥님
# GDE
# 풍부하다
# Kaggle
# questionanswering
# 15분
# ElasticSearch
# JS
# 맥스렝스
# 파리
# 미터
# 아래층
# 위층
# probing
# 커머스
# 퍼널
# 추리
# RobertaForSequenceClassification
# 쓸모없다
# 손해
# 으음
# 구성만
# MODEL
# NAME
# AutoModel
# defalut
# 박히다
# 내야
# Ke
# 큐브
# 뻥튀기
# Topk
# 랭귀
# 우와님
# 꼽아
# 디코터
# 디코딩
# 꼽으
# teacher
# forcing
# 그레이드
# 재시
# SSDC
# requirement
# 무성
# translator
# 배달
# 퍼거걱
# 할런
# 똥컴
# 빅모델
# 첨언
# 굴
# 추상
# 해부
# 신경과학
# 벅차다
# 최재천
# 유튭
# 모방
# 잘번다
# 내공
# 왕
# 그춍
# 나왓었어
# 싫어지다
# 뉴럴링크
# 머스크
# 복잡계
# 달이다
# 특허청
# models
# learners
# 겔겔겔
# SOD
# KoElectra
# Bigbird
# Multilingual
# lingual
# 스칼라
# 교내
# 보물창고
# 화생
# 스토리
# 참전
# 님말
# mbert
# pko
# 안됫넹
# 따끈따끈하다
# 신상
# 묶여서
# 번쨰
# 크흐흠
# 될때잇엇을
# 시간복잡도
# comment
# bounded
# 돌기
# 이서
# modelname
# 해덩
# isinstance
# difference
# Expectation
# filters
# Lunar
# 예정자
# 라거
# 라이트닝
# SPLADE
# 작동시키다
# Size
# 오르락내리락
# throughtput
# 추산
# 쓰루풋
# throughput
# sec
# Step
# cased
# autoTokenizer
# ElectraTokenizer
# autotoeknizer
# electratokenizer
# 프린트
# autotokenizer
# xD
# units
# 딥초
# modelForSequenceClassification
# 양해
# 맞을껀데
# embeddimg
# ntp
# 개조
# NET
# Predict
# NAT
# forwarding
# 멘붕
# 재생
# denosing
# nar
# 우연히
# 임베딩일
# 장일
# demonstration
# Prompt
# Huffon
# 임베잉
# mel
# spectrogram
# predicted
# 672
# 731
# crop
# 불안
# 섬찟
# 섬찟하다
# 보는데
# 셔
# 쩍
# TTS
# 태스크신
# 시엔
# 티쳐포싱
# 구성원
# 여행지
# 동아리
# 연예
# 로군요
# Null
# DAT
# tts
# vocoder
# hifi
# loader
# 어요
# Hwang
# 찌라시
# 퀀텀
# 점프
# Sparsity
# 절감
# 튜링
# 코걸이
# 귀걸이
# 거실
# 체리피킹
# 중상
# stay
# 유토피아
# 인터스텔라
# 서연고
# 카포
# 꺾다
# 자콥
# 낟
# 92150193
# 개인화
# 사려
# 최강
# 밟다
# 퍼오
# 어찌저찌
# 빡셀수
# 35분
# 주고
# 질의
# 디지다
# 재일
# 텐데요
# 트윈
# 영화리뷰
# 안드네
# 꼐
# 멀티턴
# 페르소나
# 장기간
# 예진
# 초이
# 잘만
# moe
# perturbation
# enhanced
# SSL
# 접목
# 아득해지다
# Relphomer
# Graphomer
# Gophomer
# 만용
# relphomer
# KGQA
# 제대
# 온톨로지
# captum
# 낭만
# 봄
# 무릎
# 탁
# By
# 제프리
# 힌튼
# triton
# Dict
# two
# depth
# Nest
# 서하
# 재귀함수
# pycharm
# pbtxt
# 수동
# 작성중
# Question
# Answering
# 골드
# 출입
# 증
# 기업체
# 희생
# 낳다
# 끙끙대다
# 종량제
# 돌리시
# Aaai
# 풀타임
# 자린
# 바라지
# 명맥
# 엄꾼용
# 녀
# 배움
# 심화
# 특대
# 학비
# 장학금
# 핏하
# 똥망
# 아려
# 짜리보단
# 생업
# 떠보다
# 등록금
# 재무
# 원활하다
# 힘숨
# 교슈님
# 후행
# esg
# 구심
# 지구
# 머델
# 코로나
# 말인가에
# 무르익기
# 기사화
# fed
# 금융투자
# 절취
# 인위
# Pplm
# ctrl
# 과소
# 과대
# spm
# ratings
# dropna
# write
# join
# 숙제
# 센서
# 파형
# logistic
# 창세기전
# 로지
# 스틱
# Sklean
# 케라스
# 독버섯
# 식용버섯
# 식용
# 버섯
# 으님
# torchvision
# timm
# KoDiffCSE
# Using
# beneficial
# sized
# note
# diffusionLM
# 루머
# autograd
# 해봣을때
# Forwarding
# Layer
# 오버헤드
# 직하
# division
# Total
# Plm
# Naacl
# hlt
# 어절
# Dacon
# 확답
# 벤처기업
# 스튜디오
# 쇼핑몰
# 어나더
# 대구
# 보고오다
# 감독
# 격려
# 예감
# 도둑
# 심보
# 신기다
# adaptation
# 창업
# 벌리다
# 처단
# 티맥스
# 티맥스소프트
# 칸막이
# 작업실
# 차별
# 혀
# 끌끌
# 왜인
# 연고
# 설포카
# 천정
# 더받을껄
# 사병
# 병특
# 웃기
# 쩐다
# 만주
# 절하
# SPK
# 간당간당
# 갈등
# 내규
# 갈릴
# 설카포
# 갈증
# 군데
# 헤비
# 제풀이
# 빵꾸
# 인증
# 유심
# 자알
# 지독하다
# 얘넨
# CMU
# 존댓말
# 반말
# styler
# nLP
# 다양해지다
# 용언
# 순서도
# 평행사변형
# 다이어그램
# 나부랭이
# 애매모호하다
# 재범
# 주화
# 또다른
# SNE
# 이백만
# lts
# 끼치다
# bpemb
# opt
# 125
# variables
# needed
# been
# modified
# inplace
# 18432
# which
# AsStridedBackward
# expected
# backtrace
# further
# above
# shows
# changed
# there
# anywhere
# later
# Good
# luck
# retain
# opyrator
# gradio
# Streamlit
# 듬
# 발안
# kospacing
# hanspell
# 요긴
# 키위
# Konlpy
# 대항
# 진영
# koalanlp
# 코알라
# springer
# 오렐
# 정오표
# 에세이
# 세련되다
# 와쓰
# 입양
# 존버합니
# Datasets
# tags
# BIO
# intger
# 인덱싱
# Ner
# 말뜻
# ORG
# 쪼개지다
# 에측
# corporation
# corp
# 출처
# Rhee
# 도거
# seqeval
# 엉망
# 고딩
# 느데
# 봣따
# 싸인
# nll
# implemented
# Float
# 브런치
# 입닏
# 고치
# 정원
# 꽉
# 아지
# 오라기
# Ul
# Why
# 금단
# bag
# mapping
# 멉니
# disambiguation
# 후속
# 중구
# 난방
# nonlinear
# 오브젝티브
# 진실
# 후후후
# deletion
# 제너럴
# signal
# Decoder
# infilling
# ordering
# Dsba
# exT
# 생물학
# reasoning
# dec
# scale
# up
# 쑤시다
# 쏟아지다
# predictive
# coding
# future
# elmo
# 산발
# 줄기
# 세밀
# 지해
# 양쪽
# 다이지
# 유추
# Deletion
# Infilling
# Rotation
# Shuffling
# 먹는
# 대명사
# 항
# 알아듣다
# 가슴
# 웅장
# 토론자
# 파고들다
# Jarvis
# 아이엠
# SS
# Elmo
# 정인
# 미적
# 삼다수
# 160000
# fold
# 나누기
# winodw
# Remote
# SSH
# 폴드
# 애폭별
# kfold
# gray
# motion
# screen
# 누수
# 엠바고
# 조은영
# textual
# milvus
# 연합학습
# Was
# asked
# gather
# along
# were
# scalars
# will
# unsqueeze
# BCE
# CE
# 멀어지다
# 환곡
# 평균값
# criterion
# Mean
# traceback
# term
# bot
# 같이는
# fish
# 챗봇쪽
# 오리꽥님
# 방긋
# 친근하다
# 외모
# 프랑켄슈타인
# dialogbert
# 린정
# compatible
# 설문조사
# 퍼블릭
# 꼽았습니
# 행패
# 무심코
# 스런
# indentation
# 내려오다
# 껏켯
# remove
# 인덴
# 테이
# 인덴트
# bootstrap
# importlib
# external
# 미궁
# 688
# 176
# indent
# 문명
# 서브라임
# 찝찝하다
# SentenceTransformer
# miniLM
# mpnet
# 임베딩후
# pca
# Large
# 젝션
# 야식
# 유발
# 여왕
# 아랍어
# 국어교육
# 창작
# 전교생
# 패널
# 문화재단
# 두려움
# 앞서다
# 부합
# 학적
# 지문
# 건들
# 중요성
# 유주시
# Stop
# Frequency
# penalty
# Presence
# 은또
# 영시
# 습니
# 글쓰기
# 낯설다
# 퇴고
# 집체
# 이시고
# KoGPT
# repo
# 쇄
# 덴
# 인터페이스
# 개개인
# 크롬북
# 한적
# 도구로
# 교육장
# 흐흑
# 자닌감
# 듭
# 참관
# selfhost
# 처가
# 신규
# 친숙해지다
# 친해지다
# 생명체
# Rouge
# 루즈
# 진로
# 루쥬
# 만이라도
# Temperature
# 루지
# 맞서다
# 시집
# 국문학
# 기울이다
# 공포
# 라디오
# 투르크어족
# 펀딩
# 중앙
# 터키
# 아제르바이잔
# 순수문학
# 으로야
# 클껄
# 전인
# 못마땅하다
# 타이즈
# Low
# 투르크
# 어족
# fednlp
# 세팅해
# 여간
# 표제어
# 어간
# 파인튜닝할
# 거가
# 자장
# 볶다
# importance
# Cant
# 시그널
# ROI
# 임배딩벡터
# 얽히다
# 투벡
# 네거티브
# 상정
# 백프롭할
# 백프롭
# 대통령
# linking
# 백터
# 했구욤
# laye
# 워드투벡
# 거티브
# 이경우
# 자초
# 기보
# entities
# relation
# 링킹
# 시지
# 읭
# 백프롭시
# 라이즈
# 도일
# Self
# mlgalaxy
# blogspot
# ssl
# 확산
# unsuper
# Supervision
# knn
# 총칭
# 보완재
# 용례
# 두부
# 얀르쿤
# unsupervied
# 케잌
# 체리
# unlabeling
# 얀
# 르쿤
# 사람이름
# Ssl
# 초창
# 나왓을때
# 재탕하다
# 전치
# 일맥상통
# 뭐어쨋
# 장르
# 의라
# 적당
# 먹보
# 더욱이
# 답정너
# 브랜딩
# 산업혁명
# mbc
# SBS
# 톱
# 이승우
# 병맛
# 지성
# 우물우물
# 메시
# 치맥
# ON
# 내놓다
# 송길영
# 부사
# 정치학자
# 돕다
# 정치학
# 테크니컬
# 리젝된다
# academic
# 풀기
# lexicon
# 극성
# 어흑
# 사회학
# 인문과학
# 사회과학
# 스러운
# 어쩌저찌
# 뜸
# 열중
# haiderwaseem
# wp
# uploads
# Twitter
# ACM
# 상해
# 시뮬레이션
# 뮬
# 테크모
# 살인
# 황인
# 나상호
# 승자
# 강퇴
# 오카
# 쒸익쒸익
# 우루과이
# 무시무시하다
# 격수
# 결승
# 수비수
# 뱅탕
# 족
# 누녜스가
# 벤탄쿠르
# 미드필더
# 발배르데
# 수미
# 두근두근
# 배다
# 카바니
# 슈퍼세이브
# 쫄깃쫄깃하케
# 까비
# 홈런
# 의조
# 올림푸스
# 슛
# 독수리
# 월드컵
# 선제골
# 보군뇨
# 전범
# 골대
# 태세
# 쫄깃했네
# 후반전
# 2010년
# 무승부
# 후반
# 80분
# 스트라이커
# 황의조
# 올림피아
# 쿠스
# 수아레즈
# 2010
# 리버풀
# 노팅엄
# 커녕
# 그리스
# 주전
# DNA
# 채은성
# 유강남
# 이형종
# NA
# 인듯
# 코너킥
# 아오
# 갘
# 보람
# 강팀
# 2006년
# 치아
# 레즈
# 남아공
# 안정환
# TV
# 포를란
# 박지성
# 누
# 누녜즈
# 기복
# 수비
# 중거리
# 포
# 이강인
# 못해
# 조커
# 강인
# 선수
# 슛돌이
# 이네요
# 미쳣다
# 외국산
# rnt
# 유효
# 슬
# 스르
# 사르다
# 정우영
# 홈
# 중원
# 쇠
# 가쟈
# 여가량
# 방심
# 금물
# 둔하다
# 메이
# 공수
# 빌드업
# 뻥
# 석현준
# 김신욱
# 왜용
# 골짜기
# 신나님
# 베르데
# 화장실
# 얇다
# 갑툭튀
# 휘유
# dk
# 흥민
# 7분
# 세레머니
# 귀엽다
# 마요르카
# 쾌
# 지리
# 코너
# 고딘
# 지린다
# 2분
# 차고
# 순이
# 왼발
# 짞
# 수비대
# 탈진
# 멕시코
# 빠따
# 1998년
# 경질
# 완쾌
# 호날
# qqp
# eunjeon
# 메캅
# 비타
# NP
# JX
# NNP
# VCP
# EF
# JKO
# 동록
# XSA
# ETM
# 계씬가
# Since
# contain
# measure
# performance
# obtained
# via
# online
# therefore
# felt
# better
# since
# would
# allow
# us
# obtain
# Thus
# exploration
# considered
# 290
# questi
# parser
# Haystack
# 21366
# 택배
# dl
# 굿펠
# 겐
# ProbML
# 맨첨
# 거르
# 꼬투리
# 정설
# 혈통
# 국적
# 마시기
# 인종
# 얹다
# 유학생
# 조작
# 솔솔
# 색안경
# 본분
# 있을런지
# 내인
# 혈연
# 학연
# 연구윤리
# 개도국
# 후진국
# 유령
# 선량하다
# 기정
# 견해
# 학자
# 자국
# infernece
# Post
# 바꿈
# Top
# Prediction
# 새우다
# paragraphs
# sentences
# paragraph
# characters
# upper
# median
# commas
# 빈약하다
# 빈약
# Infernece
# Longformer
# 아주아주
# 개미지옥
# 수듄
# 널렸
# 해적
# 거마
# tool
# LanguageTool
# java
# detected
# Please
# jvm
# Java
# 좋습니딘
# Prerequisites
# higher
# installation
# care
# downloading
# may
# Otherwise
# manually
# unzip
# resides
# 인고
# JDK
# tutorial
# 조그만
# English
# Wikipedia
# BookCorpus
# pytorchic
# 웹페이지
# 세팅된
# Copy
# mechanism
# rounding
# interval
# round
# mp
# tp
# megatron
# 존
# offloading
# nvme
# 저하
# 밀림
# 다름없다
# 마우스
# 휠
# 시가
# 우리말
# 자료형
# 복잡
# 라시
# 랜드
# 병기
# 신입사원
# 불가피하다
# 불참
# 초코
# session
# 대동단결
# 영영
# 구요
# noun
# Okt
# virtualenv
# pipenv
# 존버함다
# 어쩌지
# 조만간
# installer
# poetry
# executable
# 2020년
# lib
# 미니콘
# 소가
# 콘다사
# 환경셋팅
# 스톱
# Pip
# 커맨드창
# 글꼴
# 동글동글
# 해진
# ipywidget
# 짜증
# pypoetry
# 상위호환
# 컨다
# 오마이갓
# torchaudio
# cudatoolkit
# forge
# Only
# cpuonly
# 쿠타
# 쫌
# 슥
# 골치
# 나니요
# ZeroS
# 피곤하다
# contaniner
# 때였스빈다
# 훨신
# 페러렐리즘
# Deepspeed
# 페러렐
# hf
# 셔닝
# 메가트론
# 패러렐
# 파티셔닝
# 메롱
# 궁금햇습니
# 합치기
# 배정
# Optimizer
# PP
# 하이브리드로
# 어셉
# 할당량
# select
# iloc
# 정수형
# 행별
# myfunc
# axis
# 갈겨
# 렐
# pypolar
# 폴라
# pypolla
# polars
# 페럴
# 러렐
# 플라이
# 폴
# 키값
# items
# 발라
# 시제
# indexError
# col
# 브니
# 정규
# 등분
# 산성
# 위배
# 크러스칼
# 월리스
# 로거
# stdout
# logger
# 감싸다
# 해제
# 했슴다
# element
# 저리
# 천천히
# trans
# 득점
# 전이랑
# 러시아
# 등등하다
# 피지
# 몸싸움
# 탄력
# 무득
# 무재
# 재배
# 비키다
# sbs
# 버렷
# 에혀
# 홍명보
# 투지
# 돌파구
# 바르샤
# 체육
# 쨋
# 김진수
# 전함
# 캐애글
# 진수
# 94
# 스페인
# 옴
# 노답
# 실화
# 아이유
# 험담
# TMI
# 웃
# 넣엇으
# 소원
# 대감
# 가다듬다
# 탈탈
# 흥분하다
# 승리자
# 배민살걸
# 떼돈벌
# 승률
# 초콜릿
# 극적
# 이팅
# 군입대
# 라인업
# pl
# 사오다
# 귀화
# 구단주
# 브라질
# 흥이
# 부리
# 쫓겨나다
# 골기퍼
# 날렵하다
# 골키퍼
# 몸빵
# 이강
# 권창훈
# 빠잉
# 빵후
# 빠이
# 지렿다
# 깝깝
# 옆집
# 비명
# 투야
# 이거지
# 우뢰
# 발사
# 정화
# 헤딩
# 영점
# 으아
# 동점
# 리그
# 팔로워
# 카누
# 국승
# 붕대
# 투혼
# 자키
# 윌리엄스
# 양보
# 28분
# 동점골
# 키퍼
# 에헤
# 머뭇거리다
# 흥민손
# 액면가
# 아바타
# 나비
# 40분
# 41분
# 백퍼
# 10분
# 탄탄하다
# 단단하다
# 밀리다
# 김승규
# 조현우
# 킥
# 경우의수
# 포르투갈
# 설렁설렁
# 우의
# 대들보
# 픽픽
# 쓰러지다
# 만더
# 부상
# 레드카드
# 대표팀
# 는데
# 45초
# 심판
# 앤서니
# 테일러
# 얌전하다
# 영웅
# 흥민좌
# 포루투갈
# 예절
# 소니
# 발휘
# 그르게
# 토토
# 골도
# 마크
# 대머리
# 대인
# 글킨
# 인신공격
# 나무
# 업뎃한거
# 포투
# 득실
# 말아먹다
# 어시
# 레프트
# 풀백
# 대체재
# 마땅치
# 대가리
# 안들엇네
# 2002월
# 드컵
# 공격수
# 김민재
# 가뭄
# 콩
# 제적
# 강인덕
# candidates
# 오니
# 포르투
# 우르
# 골차
# 나왓넹
# 링링
# 닥터
# 스트
# 1400만
# 개의
# 3등
# 픔
# 퓨대폰
# 휴대폰
# Levenshtein
# If
# ngrams
# order
# grams
# To
# avoid
# harsh
# behaviour
# overlaps
# found
# used
# CrossEntropyLoss
# 클럭
# 캐쉬
# 일케
# 뚜
# 따님
# tag
# 지네
# Kss
# 수십만
# 분노조절
# 장애
# basic
# 에욤
# 죄송
# SMT
# Smt
# Rnn
# 단무지
# 유력하다
# multiturn
# selection
# sst
# 괜춘
# photo
# 번시
# 페티
# gradnorm
# 칸
# SelfAttention
# BERTModel
# Valid
# 빔
# 짧게하다
# beamsize
# citing
# Beltagy
# Long
# author
# Iz
# Matthew
# Peters
# Arman
# Cohan
# arXiv
# 2004
# 05150
# 빨갛다
# 생뚱맞
# xn
# independent
# standard
# normal
# exploding
# Paper
# MONTI
# 무었
# Monti
# 터셋
# 집계
# Douban
# CFN
# Glocal
# 인도네시아
# 버트쪽
# chit
# oserror
# errno
# too
# many
# 마소
# 16384
# 캡션
# Ctrl
# 아래첨자
# alternative
# hierarchical
# Noise
# Estimation
# NCE
# introduced
# Gutmann
# Hyvarinen
# applied
# Mnih
# Teh
# posits
# able
# differentiate
# hinge
# Collobert
# Weston
# who
# 튜
# 최고봉
# 흐음
# 실몽입니
# 뜨닝
# 근간
# 방기
# 한시
# 중순
# 까지로
# 넉넉하다
# 롬님
# 클래시
# 피케
# 118
# cur
# tolist
# 임베
# 딩시
# 태깅용
# 난잡하다
# 토요일
# 맑다
# 중부
# 지방
# 구름
# 강수량
# 께선
# PREMISE
# 엔딩
# 극치
# 뇌피셜입니
# 협소
# 읍읍읍
# 평
# 법률
# editable
# 손민수
# 재개발
# 조렇다
# 짯는
# plotly
# 5초
# static
# 조아영
# 줌
# textattack
# 테크닉
# TTA
# 딜레
# 버벅임
# Vs
# 그러몀
# 썩다
# 데탑
# 논외
# 동성
# 우왕
# 연합
# 빅스
# TOBIG
# 활동량
# 주저
# 제보
# yeah
# dapt
# plt
# Histogram
# sequenceclassification
# barplot
# histogram
# OMR
# 제지
# 빼앗다
# horizontal
# barh
# 구직
# TO
# 따내다
# 굴러가다
# 실험실
# 연구기관
# pega
# sapn
# 나은지
# Processing
# Unit
# 퀼봇
# bf
# chatGPT
# 정철
# 관동
# 봇곡
# 알렉산더
# 공자
# 오진
# 윌리엄
# 슈바이처
# 썸녀
# 웰
# 폭딜
# 취한
# 시비
# 수천만
# 명과
# 포자
# Kc
# 준범
# Pko
# callback
# defined
# Lightning
# 13분
# 파팅
# 고의
# 드가자잇
# 가즈아잇
# 극혐
# 져서
# 싸가지
# 헣허
# 봅닏
# 조리돌림
# 왤케
# 막혓
# 패널티킥
# 김영권
# 골로
# 곡골
# 김영
# 나이스
# 꺄
# 강두
# 광화문
# 어깨
# 치네다
# 뻥뻥차
# 준빈쿤
# 포프
# 닮다
# 쫄깃
# 전반전
# 강가
# Horta
# 병풍
# 호감
# 어씨
# 호날두
# 허탈하다
# 방탕하다
# 여론
# 위축
# 휴식시간
# 이죠
# 능민
# 닥터스
# 14032
# 20초
# 사당
# 유니버스
# 황희
# 챀
# 우리형
# 병장
# mvp
# 찬쩌
# 여윽시
# 시원시원하다
# 찬찬
# 징조
# 대에
# 아슬아슬하다
# 윙백
# 의족
# 전술
# 38분
# 오필승코리아
# 이후에
# 6분
# 곡로
# 독도
# 네미
# 쳫다
# 가브
# 예언가
# 으어아
# 으아아
# 흔들리다
# 에이스침대
# 침대
# 드러눕다
# 취득
# 법칙
# 추론엔진
# 8분
# 편의점
# 초콜렛
# 사드
# 4분
# 똥줄
# 타네
# 쫄리
# 12년
# 강전
# 끌
# 10초
# 정신과
# 의방
# 민수
# 휘슬
# 안티
# 와아아
# 이이이이
# 픂
# 피날레
# 화려하다
# 날두
# 브이
# 만큼은
# 조국
# 신의
# 한수인
# 히딩크
# 삼바
# 쌈장
# 하남
# 닥터밴트
# 라틴
# 선방
# 애국
# 반두
# 잠
# 깻네
# 대진표
# 높슴다
# 강요
# 마무
# 승점
# 앞서서
# 활약
# 맹활약
# 혼신
# 위기
# 봉착
# 25분
# 킬
# 건네다
# 발판
# 이뿌다
# 부진하다
# 회심
# 골문
# 만세
# 킹카
# 정보과학
# 본부
# ksc
# kcc
# 저널썻다
# 게으름
# 나뉘어지다
# 디리클레
# lsa
# 흐하
# 90시간
# 그날
# 쌈바춤
# 충
# 금기
# 레이텍
# usepackage
# kotex
# tex
# documentclass
# Mongc
# ChatGPT
# 가상머신
# 볼륨
# 넘버
# 152
# 50000
# LapTop
# 경악
# 롭
# Electra
# 스탠다드
# 엘렉트라
# 다예
# 궁금햇
# 신재생에너지
# 정하진
# Scopus
# even
# 달인
# chatgpt
# instrut
# 구사
# 감다
# 프롬프트
# 포커싱
# 왕왕
# 손익
# 잼민
# 썻
# 버디
# 세이클럽
# 싸이월드
# MZ
# 씨익
# 112198327
# FastText
# 승부
# 1000등
# 맞혔는데
# 167
# 110
# 연말
# award
# 올라타다
# Diffusion
# Lm
# 뿡
# trie
# 628
# 앱스
# 재미있다
# 한판
# 나왓나
# 옴메메
# 연장전
# 유니폼
# 커뮤
# 에데르
# 송
# 기마랑이스
# 프레드
# 파비뉴
# 마르티넬리
# 수스
# 기량
# 일본도
# 친선경기
# 초사
# 뭡
# 잉글랜드
# 프랑스
# 음바페
# 조로
# 도어
# 락
# 부수
# 무시무시
# 북산
# 있는딩
# 버티고
# 어드
# 륻스
# Jeff
# dean
# 극명하다
# 매너
# 확실
# 어케될
# 땀
# 벤버
# 기레기
# 김학범
# 이용수
# 차기
# 식겁
# 최용수
# 축협
# 언플
# 스포츠
# 양궁
# 금메달
# 세포
# guess
# 생김새
# 아기
# delivery
# 개국
# 두뇌
# Endoplasmic
# reticulum
# 바늘
# 주사
# 광견병
# Domain
# Catastrophic
# forgetting
# Sample
# 어체
# PreTraining
# BioBERT
# 감기
# 채소
# 맛점
# 천재교육
# genia
# 이끌다
# 예비
# 멘토
# digital
# 수강
# 800
# https
# DataLoader
# 5976
# killed
# Bus
# shared
# try
# raise
# your
# shm
# 건정도에서
# 8만
# 12만
# MODUCON
# 외롭다
# BeyondAIByCommunity
# 넓어지다
# 접점
# 영감
# 교류
# AM
# 연세대학교
# 백양
# 누리
# dependent
# speaker
# verification
# pr
# 뎃
# 열람
# 불합격
# 승만
# 펀치
# 통보
# 리크
# 루터
# 헤드헌터
# 만원
# 직도
# 라이츄
# 한자리
# 밝다
# 듣보다
# 오죽하다
# 근면
# 성실하다
# 책임감
# 력도
# 절실
# 주절주절
# 싱숭생숭하다
# 컨플루언스
# 빠릿
# 저엽
# Jira
# ci
# SequenceClassifierOutput
# eacl
# 특별
# 집기
# 6월
# 비대
# 놀랍다
# 080
# 863
# 5448
# 디노
# adafactor
# 보완
# 발상
# denoise
# 튜닝할
# 견고하다
# 대장
# 웃픈
# decdoer
# endocder
# 니지
# 민세
# 안개
# parametric
# 얘내
# 관여
# 상호
# 마이크로소프트
# uni
# perceiver
# rl
# augmented
# 방면
# 다가가다
# 까짘
# 파서
# 신학
# 철학
# 유공
# Bot
# 위쪽
# 이리저리
# Simsimi
# simsimi
# 헤이븐
# 일어난다
# module
# stance
# neutral
# readlines
# skiprows
# skid
# 졸논
# 찰떡
# 찰
# 꼬멘틀
# 214
# 기면
# fastText
# 워드임베딩
# 리셋
# 덮다
# values
# ElectraDataset
# enemerate
# 안건
# iter
# enum
# disk
# folder
# 반하다
# 응축
# 핮
# 있어욤
# 메터
# 오브
# 젝티
# 풀때
# dumped
# Nmt
# Apple
# reset
# apron
# 앞치마
# 계류
# Wx
# fully
# connected
# 됐슴다
# divide
# conquer
# 그거슨
# 불통
# 인감
# 호통
# 무관심
# 미덕
# 친절
# 배려
# 예스맨
# 매주
# 바짝바짝
# 궁합
# mbti
# 홈피
# 교원
# intp
# 죽빵
# Y
# 우아
# 분노
# 육탄
# 경찰차
# 휴강
# 막내
# 졸업생
# 6년
# 은퇴
# 은퇴식
# 간직
# 텀블러
# 폭탄
# 무사
# 위원회
# 테뉴어
# 법안
# 캐디
# 근로자
# 무기한
# 주먹
# 논자
# 무능하다
# 열역학
# 전자기학
# 반응속도론
# 결정학
# 뭐더
# 재료공학
# 푸리
# 청강
# 날인
# 대만
# 정역학
# 칠판
# 난무
# turnitin
# 레퍼런스때문
# 애정
# SDE
# Stochastic
# Differential
# Equation
# 분자
# 지동
# ENTJ
# ISFP
# entj
# 기구
# 선풍
# 계절
# 틀어지다
# 어쩌겠습
# 파란약
# 사회생활
# classify
# intelligence
# entp
# 가바
# timer
# four
# nunbers
# 티제
# 엣티제
# 늅늅
# Where
# 아부다비
# 땡큐
# 앤드
# 주짓수
# 선수권
# 비만
# backtracking
# MMA
# 빡센가
# 전무
# 드밀기
# kci
# 원후
# 닥치다
# 언변
# 빡센거
# 커트라인
# 하필
# 실연
# 계해
# 자소
# azure
# 후회
# 지포스
# 7600
# gt
# 달전
# 7800
# GT
# 2005년
# 쯤인가요
# 8800
# GTX
# 260
# 부잣집
# 추억
# 750
# 760
# mg
# 글켓네
# 치명
# Tie
# 감명
# Davinci
# 신약
# 유플러스
# 장학생
# 달라짐
# 플젝경험
# 지망
# 휴학
# 24년
# 채운
# 증명서
# 752
# 번재
# 육안
# 하띾
# notepad
# BOM
# 암살
# VScode
# HAND
# 인사말
# 조지
# ab
# 의학용어
# 되겠쥬
# 태반
# glioblastoma
# GBM
# 소통
# 얐
# 굴레
# 끔찍하다
# 어로
# DX
# IoX
# 구상
# 내외
# 요구사항
# 어쨋들
# 에서라도
# 만두
# 격리
# 비자
# 어탠션되
# 도식
# 패치
# flamingo
# donut
# 글씨
# 악필
# multomodal
# 어텐션값
# explainability
# power
# explainable
# tell
# captioning
# 구려
# overflow
# 사두
# 3만원
# 플랙스
# 코드량
# 같슴다
# 크로아티아
# 리바갑
# FM
# 입하
# 리바코
# 비치
# 라이코비치
# 잭팟
# 최곱
# 코지
# 피티
# Qa
# generetion
# emblp
# 보곱
# 끼어들다
# 생성태스크
# optimum
# 뷰룰
# 누적
# 효과음
# 문인
# 아낰
# qvalue
# St
# 거꾸로
# 둘째
# binarized
# action
# 무수
# 차분하다
# 동이
# ORelly
# 합리화
# 곘
# 지름신
# 써놧는
# 귱굼한거눈
# 인퓻
# 인퓻울
# 타이타닉
# 아이리스
# 펭귄
# 성해
# OpenReview
# 신입생
# 푹
# 예습
# 슬러
# 익히셍
# Grad
# CAM
# 딥뉴럴
# 픽셀
# Explanable
# Saliency
# chatGpt
# 러신
# chargbt
# 정시
# 간결하다
# 미해결
# sentinel
# Wordpiece
# 폴로
# 한이음
# 멘토링
# 지역별
# 멘티
# 롤러
# 그간
# hoxy
# 킾
# 수요일
# KPMG
# 혼성
# 꼰대들
# 칙칙하다
# 한겐
# 여자도
# 비디오
# 이러다가
# 여성
# 발품
# 회계법인
# 펌
# ERP
# 원체
# 장부
# 캄
# 사하다
# 몰랏어
# kpmg
# 진보
# 분더
# 베타테스트
# 삼정
# 남았슴다
# 범블비
# 브로커
# 위성
# 구몽
# 빡셉니
# 버트트트님
# discriminator
# 명제
# 더불다
# 성기
# Discriminator
# Real
# xl
# reformer
# switch
# meta
# former
# byt
# Krafton
# 천만원
# Rraw
# dynamic
# dinamic
# implementation
# performed
# once
# resulting
# same
# times
# ways
# seen
# pyCompare
# bland
# altman
# 조가
# 괴상하다
# STEM
# 구성요건
# targets
# 선무당
# advise
# 스팬길이
# 이제현
# Ph
# Principal
# Engineer
# KDP
# ZOOM
# 수줍다
# EOST
# 주얼
# sds
# 불알
# KIER
# cu
# wordpiece
# 은좀
# stratify
# spanbert
# 불쾌하다
# 망설이다
# 중립
# 팝팝
# 잘해주다
# 유치원
# 아빠
# 아드님
# 덜하다
# 의역
# 깜짝깜짝
# 놀랄떄
# Generative
# DDPM
# 쳐다보다
# 꾸역꾸역
# 삶
# 재밋었는데
# 무조
# 착각
# 잠자다
# 팅해
# 퇴근이라면
# 6시
# ddpm
# davinci
# curie
# blenderbot
# 비서
# RobertaForclassification
# 멀티태스크
# 재학생
# 폭주
# 꾸리
# 남녀
# 상경
# 이공
# 밸런스
# GloVe
# 양준혁
# 므
# 알리다
# 분산학습
# federated
# flwr
# collactor
# DataCollatorForTokenClassification
# collector
# 욘
# 밸리
# 유곡
# 이상인
# AISTRANGE
# 패들렛
# mingkkki
# catholic
# kj
# 봤느데
# 780
# 컷은
# 컷인가보네여
# 프롬프팅
# 기발하다
# DataCollectorWithPadding
# 240
# 120
# 덤
# 원소
# sort
# argsort
# 빡
# 드뎌
# 티키타카
# 좋군뇨
# 열의
# 엘리
# 먼트
# dims
# Insufficient
# capacity
# LayerNorm
# paradox
# degenerate
# 메달
# pb
# Sci
# 프로토타이핑
# 강하
# param
# 쿨하다
# 춥다
# stopwords
# tfrc
# 몇대
# 똑같슴니
# 선점형
# 적군
# 대를요
# 매크로
# hardware
# accelerators
# designed
# expedite
# provides
# researchers
# more
# provide
# 180
# 420
# 1100
# teraflops
# acceleration
# kakao
# lora
# adapters
# LoRAConfig
# 피터
# loralib
# 빌드
# 빌드다시
# 시빌
# 포스
# LoRA
# 아심
# Pod
# 감지덕지
# 클라우스
# 쉘
# 무한정
# 외적인
# 0원
# 300원
# traffic
# 고작
# 10만원
# 세팅할때
# HBM
# 죳
# 악화시키다
# 025
# 펄
# 렉
# generative
# ppl
# satisfaction
# DAU
# 룹
# 연세대
# 조음
# 댐
# 어따
# 가십
# 스크트
# SKT
# 액수
# 면담
# 융기원
# 에버
# 생활비
# 과외
# 버세
# 복지
# 굳히다
# 뵙다
# 불뿜는
# 꼬부기
# 샤워
# 박살
# si
# 주체
# 비선
# 호도
# 외적
# 내로
# 6천
# 오피
# 셜
# 성과급
# 삼전
# 불만
# 양재
# 양재시민의숲
# 숲
# 잠실
# 석촌호수
# 연구개발
# 너거
# airs
# 공채
# 매달
# 빼고
# 정보라
# HR
# 캐시
# 개편
# 당한
# 영원하다
# 꼴다
# 잠재력
# Skt
# 으윽
# 피크
# 티오
# 슼
# nc
# dx
# 들려오다
# 꼽히다
# 포토샵
# 프리미어
# ly
# FpuepL
# 데미
# 웅진
# 씽크빅
# STARTERS
# Udemy
# 인턴십
# 열사
# 막내아들
# 닷컴버블
# 하이닉스
# 처우
# 목숨
# 곡
# 앤디
# 까지라도
# 헬
# 게이트
# 책사
# 메모장
# 계산기
# 적성
# 모의
# 볼떄
# 손절
# 안당
# 작용
# 아리
# 진또
# 배기
# 아리다
# 사보
# 입초
# 뎅숑
# 특급
# 남았네요
# 퇴
# NL
# TA
# NC
# 크레프
# 원랜
# 삼상
# 전환율
# 애매
# 반전
# 나아
# 가구
# 차에
# 날수
# 모수
# 독하다
# 토나오다
# 할리
# 정신없이
# 투자가
# 엔트리
# 맵다
# 엘리트
# 카엔프
# 궁그
# 받치다
# 릅니
# 증권
# ve
# have
# 축약어
# contraction
# 밥맛
# 어린이집
# 현엽
# 축축
# 살기
# 힘차다
# 책상
# 헤드뱅잉
# 허리
# 의자
# 서서
# 해논
# 병가
# 직종
# 장시간
# 밀러
# 듀오
# 메리
# 개이득
# 운동선수
# 레전드
# 신체
# 성숙
# 담배
# 출퇴근
# 선천
# 막일
# 삼십
# 얼다
# 꽝꽝
# 직시
# 수용
# 잉여
# 자리야
# 얼어붙다
# 버블
# 과채
# 닷컴
# 브리
# 30초
# 반쯤
# 졸다
# 후의
# 기질
# 폐
# 똘똘이
# 납치
# 흡수
# 스프링
# 못버
# 생존
# 직면
# mlops
# 알짜
# 양념
# 네트웍
# 피부
# Mlops
# 파지다
# 뿐더러
# 본대
# 네트워킹
# Networking
# 상부상조
# 한다하는
# 우수하다
# 어니
# 불순
# 서구
# CUDNN
# STATUS
# MAPPING
# 오랫
# 활황
# 옥스포드
# 협
# 고함
# 뿌술려
# 썻던
# RLHF
# 출장
# 바카라
# 침투
# 시긴
# common
# crawl
# alphacode
# 어케헀누
# 우어
# libtorch
# Vanilla
# 반론
# 능변
# 보노
# probs
# 종강
# 이맘
# 상필
# 툴이에욤
# sys
# recursion
# 교
# levenshetein
# 안녀
# 성종
# hgtk
# 모종
# Aumentation
# 미스테리
# 본격
# 앤드류
# Nc
# AIHub
# 놀이터
# 레디
# 잇엇어
# 독투
# SPARK
# 플라스크
# route
# 걸치다
# 스웨터
# 아우
# 코트
# ABC
# agnes
# diana
# 녹음
# 맺다
# 끊음
# classifcation
# descrition
# postfix
# pbar
# Nature
# 캘리포니아주
# 샌프란시스코
# 캘리포니아
# Mina
# Lee
# dist
# 도착
# DistilBERT
# awsome
# 핑거프
# 핑거
# 프린세스
# 신조어
# 문외한
# 개열
# 찢어지다
# 곤조
# 왕국
# BYOL
# ema
# 안녕
# 수민
# 여즘
# 농사
# 행불
# 학쿤님
# 코웍
# 호후호후호
# Denoising
# Pre
# Down
# probe
# Uniformity
# 레터
# 영국영어
# 젠틀
# kl
# divergence
# aligned
# 정렬
# 아레띠님
# 스페이스바
# surfix
# Surfix
# 냐는
# arg
# DT
# 디시
# decoding
# SP
# 명백하다
# Decode
# Convert
# 이걸루
# white
# event
# 넵텝
# 쌔
# 프젝
# 데자뷰
# 진도
# 하브
# 송중
# 송중기
# 거울
# 송충이
# 빡셈
# 브레이크포인트
# Teacher
# Pyenv
# Anaconda
# stg
# 최최
# 플렉스
# devops
# 창창하다
# 의욕
# 한걸음씩
# 타요
# 명인
# 모루
# 도망치다
# 맛보다
# 소질
# 번벅
# cpp
# edge
# pipline
# 워닝
# 더러워지다
# UserWarning
# seem
# pipelines
# sequentially
# maximize
# efficiency
# please
# warnings
# warn
# 워닝끄
# 라고만
# 증식
# Apply
# precomputed
# bs
# heads
# seqlen
# atention
# finfo
# 크리스마스
# 코세라
# 봤슴다
# sharding
# shard
# 려면
# hftrainer
# xmp
# lite

# %%
print(model.wv.most_similar("음악", topn=5))
# Out:
# [('손', 0.9945988059043884), ('인사', 0.9943923950195312), ('2022', 0.9941294193267822), ('16', 0.9939419031143188), ('팀', 0.993897557258606)]
