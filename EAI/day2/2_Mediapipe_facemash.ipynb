# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\admin\anaconda3\envs\dha\lib\site-packages (3.4.11.45)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from opencv-python) (1.21.2)

# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\admin\anaconda3\envs\dha\lib\site-packages (0.9.0.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (3.4.11.45)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (3.19.4)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (2.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: absl-py in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (1.0.0)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from mediapipe) (1.21.2)
# Requirement already satisfied: six in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from absl-py->mediapipe) (1.16.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\dha\lib\site-packages (from matplotlib->mediapipe) (1.4.2)

# %%
import cv2
import mediapipe as mp
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_face_mesh = mp.solutions.face_mesh

# %%
drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
cap = cv2.VideoCapture(0)
with mp_face_mesh.FaceMesh(
    max_num_faces=1, # 탐지할 최대 얼굴 수
    refine_landmarks=True, # 눈동자 주변의 랜드마크를 추가로 출력할지 여부
    min_detection_confidence=0.5, # 탐지가 성공한 것으로 간주되는 얼굴 탐지 모델의 최소 신뢰 값([0.0, 1.0])
    min_tracking_confidence=0.5) as face_mesh: # 랜드마크 추적 모델의 최소 신뢰 값([0.0, 1.0])
  while cap.isOpened():
    success, image = cap.read()
    if not success:
      print("Ignoring empty camera frame.")
      # If loading a video, use 'break' instead of 'continue'.
      continue

    image.flags.writeable = False
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(image)

    # 이미지 위에 얼굴 그물망 주석 그리기
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    if results.multi_face_landmarks:
      for face_landmarks in results.multi_face_landmarks:
        mp_drawing.draw_landmarks(
            image=image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_TESSELATION,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp_drawing_styles
            .get_default_face_mesh_tesselation_style())
        mp_drawing.draw_landmarks(
            image=image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp_drawing_styles
            .get_default_face_mesh_contours_style())
        mp_drawing.draw_landmarks(
            image=image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_IRISES,
            landmark_drawing_spec=None,
            connection_drawing_spec=mp_drawing_styles
            .get_default_face_mesh_iris_connections_style())

    cv2.imshow('MediaPipe Face Mesh', cv2.flip(image, 1)) 
    if cv2.waitKey(1) == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
